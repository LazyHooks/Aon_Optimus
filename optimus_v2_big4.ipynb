# %% [markdown]
# <a href="https://colab.research.google.com/github/LazyHooks/Optimus/blob/main/optimus_v2_big4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('big4train3.csv')
df.head()
# Out:
#   Company Name Co. Designation Co. Function                Domain  \
# 0     Combined         Manager   CONSULTING  Customer & Marketing
# 1     Combined         Manager   CONSULTING  Customer & Marketing
# 2     Combined         Manager   CONSULTING  Customer & Marketing
# 3     Combined         Manager   CONSULTING  Customer & Marketing
# 4     Combined         Manager   CONSULTING  Customer & Marketing
#
#   Job Family Code
# 0            MBDM
# 1            MBDM
# 2            MBDM
# 3            MBDM
# 4            MBDM

# %%
df_test = pd.read_csv('big4test3.csv')
df_test.head()
# Out:
#      Co. Designation   Co. Function Job Family Code
# 0             Senior  Digital Nexus        Unmapped
# 1  Assistant Manager  Digital Nexus        Unmapped
# 2          Executive  Digital Nexus        Unmapped
# 3          Executive  Digital Nexus        Unmapped
# 4            Manager  Digital Nexus        Unmapped

# %%
df.shape
set(df['Company Name'])
# Out:
# {'Combined'}

# %%
df.columns
# Out:
# Index(['Company Name', 'Co. Designation', 'Co. Function', 'Domain',
#        'Job Family Code'],
#       dtype='object')

# %%
train_cols = ['Co. Designation', 'Co. Function']

# %%
target_col = 'Job Family Code'

# %%
all_cols = ['Co. Designation', 'Co. Function', 'Job Family Code']

# %%
import pandas as pd
from scipy.sparse import hstack
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split

# %%
# Load data
data = pd.read_csv('big4train3.csv')

# %%
df_test.head()
# Out:
#      Co. Designation   Co. Function Job Family Code
# 0             Senior  Digital Nexus        Unmapped
# 1  Assistant Manager  Digital Nexus        Unmapped
# 2          Executive  Digital Nexus        Unmapped
# 3          Executive  Digital Nexus        Unmapped
# 4            Manager  Digital Nexus        Unmapped

# %%
data = data[all_cols]
data = data.dropna()

# %%
df_test = df_test[all_cols]
df_test = df_test.dropna()

# %%
data.head()
# Out:
#   Co. Designation Co. Function Job Family Code
# 0         Manager   CONSULTING            MBDM
# 1         Manager   CONSULTING            MBDM
# 2         Manager   CONSULTING            MBDM
# 3         Manager   CONSULTING            MBDM
# 4         Manager   CONSULTING            MBDM

# %%
df_test.head()
# Out:
#      Co. Designation   Co. Function Job Family Code
# 0             Senior  Digital Nexus        Unmapped
# 1  Assistant Manager  Digital Nexus        Unmapped
# 2          Executive  Digital Nexus        Unmapped
# 3          Executive  Digital Nexus        Unmapped
# 4            Manager  Digital Nexus        Unmapped

# %%
# Extract features from each text column using TF-IDF vectorizer
vectorizers = []
X_train_list = []
X_test_list = []
for col in train_cols:
    vectorizer = TfidfVectorizer(max_features=10000)
    X_train_col = vectorizer.fit_transform(data.loc[:, col])
    X_train_list.append(X_train_col)
    X_test_col = vectorizer.transform(data.loc[:, col])
    X_test_list.append(X_test_col)
    vectorizers.append(vectorizer)

# %%
# Concatenate sparse matrices into a single feature matrix
X_train = hstack(X_train_list)
X_test = hstack(X_test_list)

# Split data into training and testing sets
y_train = data[target_col]
#y_test = df_test[target_col]

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# Train logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict
#         INNE       0.75      0.22      0.34        27
#         INRA       0.92      0.29      0.45        78
#         INSS       0.75      0.75      0.75         4
#         INTI       0.00      0.00      0.00         7
#         INXX       0.99      0.99      0.99       138
#         LECO       0.00      0.00      0.00        52
#         LEPO       0.00      0.00      0.00        16
#         MBCC       0.00      0.00      0.00         2
#         MBCM       0.00      0.00      0.00         6
#         MBDM       0.00      0.00      0.00       433
#     No Match       0.31      0.44      0.37      1057
#         PDFD       0.59      0.96      0.73      1462
#         PDFS       0.00      0.00      0.00         9
#         PDHD       0.42      0.06      0.10       938
#         PDLE       1.00      1.00      1.00        45
#         PDXX       0.00      0.00      0.00       142
#         PRPO       1.00      1.00      1.00        10
#         PRXX       0.98      0.98      0.98        44
#         QAXX       0.00      0.00      0.00         1
#         RABF       1.00      0.11      0.19        28
#         RASR       0.00      0.00      0.00        77
#         RAVA       0.00      0.00      0.00        74
#         RIER       0.94      0.97      0.95        60
#         RIOR       0.26      0.23      0.24       238
#         SAAC       0.00      0.00      0.00         2
#         SABD       1.00      1.00      1.00         3
#         SAPS       0.00      0.00      0.00        84
#         SAXX       0.95      1.00      0.98        59
#         SSSO       0.00      0.00      0.00        19
#         SYIN       1.00      0.90      0.95        10
#         SYPT       0.00      0.00      0.00         1
#         SYXX       0.90      0.08      0.14       119
#         TEMT       0.00      0.00      0.00        72
#         TOFS       0.00      0.00      0.00        41
#         TOMR       0.00      0.00      0.00         7
#         TOSI       0.00      0.00      0.00         4
#         TRPR       0.00      0.00      0.00         2
#         TRTN       0.00      0.00      0.00         4
#         TWXX       1.00      1.00      1.00        14
#         UEXX       0.00      0.00      0.00        35
#
#     accuracy                           0.48     21516
#    macro avg       0.35      0.28      0.28     21516
# weighted avg       0.45      0.48      0.41     21516
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
X_test_unseen = []

for i, col in enumerate(train_cols):
    vectorizer = vectorizers[i]
    X_test_col = vectorizer.transform(df_test.loc[:, col])
    X_test_unseen.append(X_test_col)
    
X_unseen = hstack(X_test_unseen)

# %%
y_test_pred = model.predict (X_unseen)

# %%
pd.DataFrame(y_test_pred).to_csv('maps_big4')

# %%
df_test
# Out:
#          Co. Designation   Co. Function Job Family Code
# 0                 Senior  Digital Nexus        Unmapped
# 1      Assistant Manager  Digital Nexus        Unmapped
# 2              Executive  Digital Nexus        Unmapped
# 3              Executive  Digital Nexus        Unmapped
# 4                Manager  Digital Nexus        Unmapped
# ...                  ...            ...             ...
# 9958      Senior Analyst             CH        Unmapped
# 9959   Assistant Manager             CH        Unmapped
# 9960      Senior Analyst             CH        Unmapped
# 9961  Associate Director             CH        Unmapped
# 9962   Assistant Manager             CH        Unmapped
#
# [9963 rows x 3 columns]
