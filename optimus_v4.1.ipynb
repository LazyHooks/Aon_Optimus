# %% [markdown]
# <a href="https://colab.research.google.com/github/LazyHooks/Optimus/blob/main/optimus_v4.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('Train.csv')
df.head()
# Out:
#                   Company Name                Co. Designation  \
# 0  Soc Gen Hi Tech & ITES 2022                        Analyst
# 1  Soc Gen Hi Tech & ITES 2022                        Analyst
# 2  Soc Gen Hi Tech & ITES 2022  Cyber Security Senior Analyst
# 3  Soc Gen Hi Tech & ITES 2022         Cyber Security Analyst
# 4  Soc Gen Hi Tech & ITES 2022                 Senior Analyst
#
#            Co. Function Job Family Code Level        TFP  Unnamed: 6  \
# 0     CENTRAL FUNCTIONS            LECO    S3   628146.0         NaN
# 1  KYC&CL Utility (KYU)            BFCM    S3   387835.0         NaN
# 2                   GTS            SYXX    I2  1868511.0         NaN
# 3                   GTS            SYXX    I1  1361648.0         NaN
# 4     CENTRAL FUNCTIONS            FAFA    I1  1133234.0         NaN
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10
# 0         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN          NaN
# 2         NaN         NaN         NaN          NaN
# 3         NaN         NaN         NaN          NaN
# 4         NaN         NaN         NaN          NaN

# %%
df_test = pd.read_csv('test1.csv')
df_test.head()
# Out:
#                       Company Name                       Co. Designation  \
# 0  Wells Fargo Hi Tech & ITES 2022  Senior Information Security Engineer
# 1  Wells Fargo Hi Tech & ITES 2022     Senior Investment Risk Specialist
# 2  Wells Fargo Hi Tech & ITES 2022              Senior Software Engineer
# 3  Wells Fargo Hi Tech & ITES 2022        Senior Infrastructure Engineer
# 4  Wells Fargo Hi Tech & ITES 2022              Senior Software Engineer
#
#             Co. Function Job Family Code Level      TFP
# 0      Technology & Data            SYXX    I4  2100037
# 1  Governance & Controls            RIER    I3  2080500
# 2      Technology & Data            ASXX    I4  1743788
# 3      Technology & Data            INSS    I4  2071378
# 4      Technology & Data            ASXX    I4  3253143

# %%
df.shape
set(df['Company Name'])
# Out:
# {'ANZ Hi Tech & ITES 2022',
#  'Allstate Hi Tech & ITES 2022',
#  'BNYM Hitech and ites 2022',
#  'Citi Corp Hi Tech & ITES 2022',
#  'DBSschenker Hi Tech & ITES 2022',
#  'Fiserv',
#  'Greatwest Hi Tech & ITES 2022',
#  'HDFC Securities Hi Tech & ITES 2022',
#  'Invesco Hi Tech & ITES 2022',
#  'Midland Credit Management Hi Tech & ITES 2022',
#  'Morning Star Hi Tech & ITES 2022',
#  'Nomura Hi Tech & ITES 2022',
#  'Northern Trust Hi Tech & ITES 2022',
#  'Soc Gen Hi Tech & ITES 2022',
#  'Statestreet Hi Tech and Ites 2022',
#  'TIAA Hi Tech & ITES 2022',
#  'Wells Fargo Hi Tech & ITES 2022'}

# %%
df.columns
# Out:
# Index(['Company Name', 'Co. Designation', 'Co. Function', 'Job Family Code',
#        'Level', 'TFP', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10'],
#       dtype='object')

# %%
train_cols = ['Co. Designation', 'Co. Function']

# %%
target_col = 'Job Family Code'
target_col_2='Level'

# %%
all_cols = ['Co. Designation', 'Co. Function', 'Job Family Code','Level']

# %%
import pandas as pd
from scipy.sparse import hstack
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split

# %%
# Load data
data = pd.read_csv('Train.csv')

# %%
df_test.head()
# Out:
#                       Company Name                       Co. Designation  \
# 0  Wells Fargo Hi Tech & ITES 2022  Senior Information Security Engineer
# 1  Wells Fargo Hi Tech & ITES 2022     Senior Investment Risk Specialist
# 2  Wells Fargo Hi Tech & ITES 2022              Senior Software Engineer
# 3  Wells Fargo Hi Tech & ITES 2022        Senior Infrastructure Engineer
# 4  Wells Fargo Hi Tech & ITES 2022              Senior Software Engineer
#
#             Co. Function Job Family Code Level      TFP
# 0      Technology & Data            SYXX    I4  2100037
# 1  Governance & Controls            RIER    I3  2080500
# 2      Technology & Data            ASXX    I4  1743788
# 3      Technology & Data            INSS    I4  2071378
# 4      Technology & Data            ASXX    I4  3253143

# %%
data = data[all_cols]
data = data.dropna()

# %%
df_test = df_test[all_cols]
df_test = df_test.dropna()

# %%
data.head()
# Out:
#                  Co. Designation          Co. Function Job Family Code Level
# 0                        Analyst     CENTRAL FUNCTIONS            LECO    S3
# 1                        Analyst  KYC&CL Utility (KYU)            BFCM    S3
# 2  Cyber Security Senior Analyst                   GTS            SYXX    I2
# 3         Cyber Security Analyst                   GTS            SYXX    I1
# 4                 Senior Analyst     CENTRAL FUNCTIONS            FAFA    I1

# %%
df_test.head()
# Out:
#                         Co. Designation           Co. Function  \
# 0  Senior Information Security Engineer      Technology & Data
# 1     Senior Investment Risk Specialist  Governance & Controls
# 2              Senior Software Engineer      Technology & Data
# 3        Senior Infrastructure Engineer      Technology & Data
# 4              Senior Software Engineer      Technology & Data
#
#   Job Family Code Level
# 0            SYXX    I4
# 1            RIER    I3
# 2            ASXX    I4
# 3            INSS    I4
# 4            ASXX    I4

# %% [markdown]
# JF

# %%
# Extract features from each text column using TF-IDF vectorizer
vectorizers = []
X_train_list = []
X_test_list = []
for col in train_cols:
    vectorizer = TfidfVectorizer(max_features=10000)
    X_train_col = vectorizer.fit_transform(data.loc[:, col])
    X_train_list.append(X_train_col)
    X_test_col = vectorizer.transform(data.loc[:, col])
    X_test_list.append(X_test_col)
    vectorizers.append(vectorizer)

# %% [markdown]
# Level

# %%
vectorizers_2 = []
X_train_list_2 = []
X_test_list_2 = []
for col in train_cols:
    vectorizer = TfidfVectorizer(max_features=10000)
    X_train_col = vectorizer.fit_transform(data.loc[:, col])
    X_train_list_2.append(X_train_col)
    X_test_col = vectorizer.transform(data.loc[:, col])
    X_test_list_2.append(X_test_col)
    vectorizers_2.append(vectorizer)

jfcol='Job Family Code'
vectorizer = TfidfVectorizer(max_features=10000)
X_train_col = vectorizer.fit_transform(data.loc[:, jfcol])
X_train_list_2.append(X_train_col)
X_test_col = vectorizer.transform(data.loc[:, jfcol])
X_test_list_2.append(X_test_col)
vectorizers_2.append(vectorizer)

# %% [markdown]
# JF

# %%
# Concatenate sparse matrices into a single feature matrix
X_train = hstack(X_train_list)
X_test = hstack(X_test_list)

# Split data into training and testing sets
y_train = data[target_col]
#y_test = df_test[target_col]

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# Level

# %%
# Concatenate sparse matrices into a single feature matrix
X_train_2 = hstack(X_train_list_2)
X_test_2 = hstack(X_test_list_2)

# Split data into training and testing sets
y_train_2 = data[target_col_2]
#y_test = df_test[target_col]

X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X_train_2, y_train_2, test_size=0.2, random_state=42)
# Out:
# <101808x1490 sparse matrix of type '<class 'numpy.float64'>'
# 	with 326417 stored elements in Compressed Sparse Row format>

# %% [markdown]
# JF

# %%
# Train logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict on test set and evaluate performance
y_pred = model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred))
print('Classification Report:\n', classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy: 0.8567429525586877
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#         AADS       0.95      0.81      0.87        72
#         AAIB       0.00      0.00      0.00         1
#         AAMD       0.88      0.64      0.74        67
#         AAML       0.00      0.00      0.00         1
#         AFAD       0.71      0.62      0.67        32
#         AFFE       0.70      0.64      0.67        11
#         AFSE       0.92      0.73      0.81        15
#         AFXX       0.80      0.57      0.67         7
#         ARCD       0.00      0.00      0.00         6
#         ARIA       0.90      0.67      0.77        42
#         ARRP       0.00      0.00      0.00         2
#         ARSY       1.00      1.00      1.00         2
#         ARXX       0.80      0.95      0.87       100
#         ASCD       0.83      0.25      0.38        20
#         ASDB       1.00      0.62      0.76        52
#         ASEC       0.00      0.00      0.00         3
#         ASFS       0.89      0.57      0.69       467
#         ASMD       0.00      0.00      0.00        13
#         ASPI       1.00      0.19      0.32        37
#         ASRP       1.00      0.19      0.32        52
#         ASSI       0.67      0.04      0.07        56
#         ASUI       1.00      0.74      0.85        43
#         ASXX       0.80      0.97      0.88      2945
#         BCPM       1.00      0.17      0.29         6
#         BFAM       0.53      0.25      0.34        40
#         BFCA       1.00      0.99      0.99       271
#         BFCB       0.97      0.93      0.95       975
#         BFCM       0.76      0.86      0.81       800
#         BFFU       0.46      0.91      0.61       183
#         BFKY       0.82      0.86      0.83       269
#         BFLP       1.00      1.00      1.00        18
#         BFPC       0.18      0.12      0.14       104
#         BFTF       0.97      0.74      0.84       104
#         BFTO       0.98      0.95      0.96       802
#         BFUW       0.68      0.76      0.72        17
#         BFWB       0.36      0.62      0.46        45
#         BSMT       0.75      0.66      0.70        64
#         CCCO       1.00      0.40      0.57         5
#         CCCW       0.00      0.00      0.00        29
#         CCMD       0.97      0.99      0.98       179
#         CCMI       0.58      0.93      0.72       103
#         CCVD       0.85      0.35      0.50       218
#         CMDO       1.00      0.33      0.49        61
#         CMDS       0.00      0.00      0.00         1
#         CMXX       1.00      0.56      0.72        16
#         CSBC       0.91      0.80      0.85        90
#         CSCS       0.00      0.00      0.00         8
#         CSED       0.00      0.00      0.00         1
#         CSEL       0.60      0.60      0.60         5
#         CSFC       0.85      0.82      0.83       330
#         CSSI       1.00      0.65      0.78        31
#         DABD       0.55      0.31      0.40        90
#         DABI       0.92      0.92      0.92       543
#         DADV       1.00      0.38      0.56        13
#         DADW       0.83      0.24      0.38        62
#         DMDA       1.00      0.29      0.44        49
#         PRXX       0.75      0.79      0.77       235
#         QAXX       0.00      0.00      0.00         9
#         QUTF       0.80      0.80      0.80        81
#         QUTS       0.99      0.96      0.98       177
#         RABA       0.75      0.82      0.79       236
#         RABF       0.80      0.84      0.82        56
#         RAPR       0.33      1.00      0.50         2
#         RARA       0.95      0.80      0.87       207
#         RASR       0.94      0.94      0.94        33
#         RAVA       0.88      0.79      0.83        57
#         RICR       0.95      0.71      0.81        49
#         RIER       1.00      1.00      1.00        18
#         RIMR       0.24      0.63      0.35        38
#         RIOR       0.93      0.91      0.92       304
#         RSSC       1.00      1.00      1.00         3
#         RSVM       0.00      0.00      0.00         7
#         RSWL       0.00      0.00      0.00         1
#         SAAC       0.90      0.86      0.88        22
#         SABD       0.93      0.93      0.93        27
#         SACS       0.00      0.00      0.00         5
#         SAPS       1.00      0.67      0.80         3
#         SASD       1.00      0.86      0.92         7
#         SAXX       0.86      0.94      0.90        33
#         SCCP       1.00      0.85      0.92        27
#         SSSO       0.76      0.87      0.81        30
#         SYAS       1.00      0.25      0.40         8
#         SYGR       1.00      0.68      0.81        34
#         SYIM       0.89      0.76      0.82        67
#         SYIN       1.00      0.64      0.78        14
#         SYIS       0.59      0.62      0.61        16
#         SYPT       0.00      0.00      0.00         2
#         SYXX       0.84      0.77      0.81       197
#         TEAU       0.94      0.94      0.94       953
#         TEMT       1.00      0.62      0.76        13
#         TEXX       0.85      0.49      0.62        35
#         TOCO       0.90      0.91      0.91       664
#         TOFC       0.96      0.96      0.96      1256
#         TOFS       0.93      0.90      0.91       113
#         TOMR       0.92      0.63      0.75        35
#         TOPO       0.67      0.62      0.65        16
#         TOSI       0.76      0.97      0.85       717
#         TRPR       0.80      0.36      0.50        11
#         TRTN       0.00      0.00      0.00         2
#         TWXX       0.92      0.63      0.75        19
#         UEXX       1.00      0.91      0.95        11
#
#     accuracy                           0.86     20362
#    macro avg       0.66      0.54      0.56     20362
# weighted avg       0.86      0.86      0.85     20362
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Level

# %%
# Train logistic regression model
model_2 = LogisticRegression()
model_2.fit(X_train_2, y_train_2)

# Predict on test set and evaluate performance
y_pred_2 = model_2.predict(X_test_2)
print('Accuracy:', accuracy_score(y_test_2, y_pred_2))
print('Classification Report:\n', classification_report(y_test_2, y_pred_2))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy: 0.7291523425989589
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#           E1       0.00      0.00      0.00        25
#           E2       0.43      0.60      0.50         5
#           I0       0.00      0.00      0.00         4
#           I1       0.72      0.87      0.79      3098
#           I2       0.67      0.66      0.67      3156
#           I3       0.70      0.59      0.64      2700
#           I4       0.70      0.83      0.76      3502
#           I5       0.76      0.65      0.70      1289
#           I6       0.64      0.20      0.31       205
#           I7       0.00      0.00      0.00        15
#           M2       0.88      0.81      0.84       222
#           M3       0.76      0.66      0.71       563
#           M4       0.64      0.70      0.67       728
#           M5       0.64      0.54      0.58       579
#           M6       0.58      0.44      0.50       322
#           M7       0.76      0.40      0.53       149
#           S1       0.65      0.55      0.60       136
#           S2       0.89      0.89      0.89      1701
#           S3       0.84      0.78      0.81      1963
#
#     accuracy                           0.73     20362
#    macro avg       0.59      0.54      0.55     20362
# weighted avg       0.73      0.73      0.72     20362
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Unseen JF

# %%
X_test_unseen = []

for i, col in enumerate(train_cols):
    vectorizer = vectorizers[i]
    X_test_col = vectorizer.transform(df_test.loc[:, col])
    X_test_unseen.append(X_test_col)

X_unseen = hstack(X_test_unseen)

# %% [markdown]
# JF

# %%
y_test_pred = model.predict (X_unseen)

# %% [markdown]
# Unseen Level + Pred JF

# %%
X_test_unseen_2 = []
z=0
for i, col in enumerate(train_cols):
    vectorizer = vectorizers[i]
    X_test_col_2 = vectorizer.transform(df_test.loc[:, col])
    X_test_unseen_2.append(X_test_col_2)
    z=i

vectorizer = vectorizers[z+1]
X_test_col_2 = vectorizer.transform(df_test.loc[:, jfcol])
X_test_unseen_2.append(X_test_col_2)

X_unseen_2 = hstack(X_test_unseen_2)

# %% [markdown]
# Level

# %%
y_test_pred_2 = model_2.predict (X_unseen_2)

# %%
pd.DataFrame(y_test_pred).to_csv('JF_x.csv')
pd.DataFrame(y_test_pred_2).to_csv('Lvl_x.csv')
frames=[pd.DataFrame(y_test_pred),pd.DataFrame(y_test_pred_2)]
maps=pd.concat(frames)
pd.DataFrame(maps).to_csv('maps_x.csv')

# %% [markdown]
# JF

# %%
# Predict on test set and evaluate performance
y_test_actual=df_test[target_col]
print('Accuracy:', accuracy_score(y_test_actual, y_test_pred))
print('Classification Report:\n', classification_report(y_test_actual, y_test_pred))
# Out:
# Accuracy: 0.9710968021993923
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#         AADS       0.00      0.00      0.00         0
#         AFFE       0.74      1.00      0.85        17
#         AFSE       1.00      1.00      1.00        19
#         AFXX       1.00      0.71      0.83        14
#         ARXX       1.00      1.00      1.00        31
#         ASUI       0.95      1.00      0.98        21
#         ASXX       0.98      1.00      0.99      7590
#         BFAM       1.00      0.93      0.96        14
#         BFCA       1.00      1.00      1.00       367
#         BFCB       1.00      1.00      1.00      2793
#         BFCM       1.00      0.99      0.99        88
#         BFKY       1.00      1.00      1.00       443
#         BFLP       1.00      1.00      1.00        94
#         BFTF       1.00      1.00      1.00       233
#         BFTO       1.00      1.00      1.00       698
#         BFUW       1.00      0.94      0.97        16
#         BSMT       1.00      1.00      1.00        26
#         CSFC       1.00      1.00      1.00       559
#         DABI       0.43      1.00      0.60       318
#         FAER       1.00      1.00      1.00        24
#         FAFA       1.00      1.00      1.00       249
#         FAFI       1.00      1.00      1.00      1538
#         FLAC       1.00      1.00      1.00       343
#         FLFA       1.00      1.00      1.00        70
#         FLLE       0.70      1.00      0.82         7
#         FLTR       1.00      1.00      1.00        98
#         HRBP       0.94      1.00      0.97        34
