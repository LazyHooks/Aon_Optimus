# %% [markdown]
# <a href="https://colab.research.google.com/github/LazyHooks/Optimus/blob/main/optimus_v4.7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('Train.csv')
df.shape
# Out:
# (152491, 6)

# %%
df_test = pd.read_csv('test1.csv')
df_test.head()
# Out:
#                       Company Name                       Co. Designation  \
# 0  Wells Fargo Hi Tech & ITES 2022  Senior Information Security Engineer
# 1  Wells Fargo Hi Tech & ITES 2022     Senior Investment Risk Specialist
# 2  Wells Fargo Hi Tech & ITES 2022              Senior Software Engineer
# 3  Wells Fargo Hi Tech & ITES 2022        Senior Infrastructure Engineer
# 4  Wells Fargo Hi Tech & ITES 2022              Senior Software Engineer
#
#             Co. Function Job Family Code Level      TFP
# 0      Technology & Data            SYXX    I4  2100037
# 1  Governance & Controls            RIER    I3  2080500
# 2      Technology & Data            ASXX    I4  1743788
# 3      Technology & Data            INSS    I4  2071378
# 4      Technology & Data            ASXX    I4  3253143

# %%
df.shape
#set(df['Company Name'])
# Out:
# (152491, 6)

# %%
df.columns
# Out:
# Index(['Company Name', 'Co. Designation', 'Co. Function', 'Job Family Code',
#        'Level', 'TFP'],
#       dtype='object')

# %%
train_cols = ['Co. Designation', 'Co. Function']

# %%
target_col = 'Job Family Code'
target_col_2='Level'

# %%
all_cols = ['Co. Designation', 'Co. Function', 'Job Family Code','Level']
univ_cols= ['Co. Designation', 'Co. Function', 'Job Family Code','Level','TFP']

# %%
import pandas as pd
from scipy.sparse import hstack
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split

# %%
# Load data
data = pd.read_csv('Train.csv')

# %%
df_test.head()
# Out:
#                       Company Name                       Co. Designation  \
# 0  Wells Fargo Hi Tech & ITES 2022  Senior Information Security Engineer
# 1  Wells Fargo Hi Tech & ITES 2022     Senior Investment Risk Specialist
# 2  Wells Fargo Hi Tech & ITES 2022              Senior Software Engineer
# 3  Wells Fargo Hi Tech & ITES 2022        Senior Infrastructure Engineer
# 4  Wells Fargo Hi Tech & ITES 2022              Senior Software Engineer
#
#             Co. Function Job Family Code Level      TFP
# 0      Technology & Data            SYXX    I4  2100037
# 1  Governance & Controls            RIER    I3  2080500
# 2      Technology & Data            ASXX    I4  1743788
# 3      Technology & Data            INSS    I4  2071378
# 4      Technology & Data            ASXX    I4  3253143

# %%
data = data[all_cols]
data = data.dropna()

# %%
df_test_2=df_test
df_test_2=df_test[univ_cols]

df_test = df_test[all_cols]
df_test = df_test.dropna()
df_test_2 = df_test_2.dropna()

# %%
#data.head()

# %%
#df_test.head()

# %% [markdown]
# JF

# %%
# Extract features from each text column using TF-IDF vectorizer
vectorizers = []
X_train_list = []
X_test_list = []
for col in train_cols:
    vectorizer = TfidfVectorizer(max_features=10000)
    X_train_col = vectorizer.fit_transform(data.loc[:, col])
    X_train_list.append(X_train_col)
    X_test_col = vectorizer.transform(data.loc[:, col])
    X_test_list.append(X_test_col)
    vectorizers.append(vectorizer)

# %% [markdown]
# Level

# %%
vectorizers_2 = []
X_train_list_2 = []
X_test_list_2 = []
for col in train_cols:
    vectorizer = TfidfVectorizer(max_features=10000)
    X_train_col = vectorizer.fit_transform(data.loc[:, col])
    X_train_list_2.append(X_train_col)
    X_test_col = vectorizer.transform(data.loc[:, col])
    X_test_list_2.append(X_test_col)
    vectorizers_2.append(vectorizer)

jfcol='Job Family Code'
vectorizer = TfidfVectorizer(max_features=10000)
X_train_col = vectorizer.fit_transform(data.loc[:, jfcol])
X_train_list_2.append(X_train_col)
X_test_col = vectorizer.transform(data.loc[:, jfcol])
X_test_list_2.append(X_test_col)
vectorizers_2.append(vectorizer)

# %% [markdown]
# JF

# %%
# Concatenate sparse matrices into a single feature matrix
X_train = hstack(X_train_list)
X_test = hstack(X_test_list)

# Split data into training and testing sets
y_train = data[target_col]
#y_test = df_test[target_col]

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# Level

# %%
# Concatenate sparse matrices into a single feature matrix
X_train_2 = hstack(X_train_list_2)
X_test_2 = hstack(X_test_list_2)

# Split data into training and testing sets
y_train_2 = data[target_col_2]
#y_test = df_test[target_col]

X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X_train_2, y_train_2, test_size=0.2, random_state=42)

# %% [markdown]
# JF

# %%
# Train logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict on test set and evaluate performance
y_pred = model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred))
print('Classification Report:\n', classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy: 0.844448816315824
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#         AADS       0.85      0.74      0.79        82
#         AAIB       0.00      0.00      0.00         1
#         AAMD       0.87      0.72      0.79       134
#         AFAD       0.73      0.65      0.69        34
#         AFFE       0.90      0.73      0.81        26
#         AFSE       1.00      0.73      0.84        22
#         AFXX       0.33      0.12      0.18         8
#         ARCD       0.00      0.00      0.00         2
#         ARIA       0.93      0.61      0.74        44
#         ARRP       0.00      0.00      0.00         9
#         ARSY       1.00      1.00      1.00         2
#         ARXX       0.89      0.90      0.90       149
#         ASCD       1.00      0.17      0.29        36
#         ASDB       1.00      0.44      0.61        71
#         ASEC       0.50      0.14      0.22         7
#         ASFS       0.89      0.57      0.70       500
#         ASMD       0.00      0.00      0.00        20
#         ASPI       1.00      0.10      0.19        49
#         ASRP       0.79      0.36      0.49        64
#         ASSI       0.27      0.05      0.08        64
#         ASUI       0.98      0.81      0.88        62
#         ASXX       0.82      0.97      0.89      5162
#         BCPM       1.00      0.53      0.70        15
#         BFAC       0.81      0.89      0.85        53
#         BFAM       0.83      0.43      0.56       255
#         BFCA       0.98      0.97      0.98       241
#         BFCB       0.96      0.90      0.93       978
#         BFCM       0.73      0.83      0.77      1059
#         BFFU       0.46      0.94      0.61       370
#         BFIS       0.00      0.00      0.00         1
#         BFKY       0.83      0.78      0.80       520
#         BFLP       1.00      1.00      1.00        19
#         BFPC       0.15      0.08      0.11       189
#         BFTF       0.98      0.73      0.84       258
#         BFTO       0.85      0.93      0.89      1164
#         BFUW       0.80      0.67      0.73        52
#         BFWB       0.35      0.53      0.42       105
#         BSMT       0.69      0.57      0.62       100
#         CCCE       0.86      0.86      0.86         7
#         CCCO       1.00      0.75      0.86         4
#         CCCV       0.00      0.00      0.00         2
#         CCCW       0.00      0.00      0.00        27
#         CCMD       0.97      0.99      0.98       188
#         CCMI       0.62      0.93      0.74       123
#         CCVD       0.85      0.28      0.42       221
#         CCVI       1.00      1.00      1.00       508
#         CMDO       0.76      0.43      0.55        65
#         CMDS       0.00      0.00      0.00         2
#         CMXX       0.98      0.90      0.94        63
#         CSBC       0.69      0.72      0.71       112
#         CSCS       1.00      0.11      0.20         9
#         CSED       0.00      0.00      0.00         1
#         CSEL       0.75      0.60      0.67         5
#         CSFC       0.88      0.86      0.87       573
#         CSPS       0.00      0.00      0.00         6
#         CSSI       0.98      0.92      0.95       137
#         DABD       0.47      0.35      0.40        84
#         DABI       0.95      0.86      0.90       588
#         DADV       1.00      0.13      0.24        15
#         DADW       0.79      0.28      0.41        83
#         DMDA       0.77      0.47      0.58        64
#         DMKM       0.00      0.00      0.00         3
#         DMMD       0.00      0.00      0.00         9
#         DMSM       0.96      0.35      0.51       124
#         EDXX       0.80      1.00      0.89         4
#         FAAG       0.81      0.34      0.48        77
#         FAAP       0.93      0.65      0.76        40
#         FAAU       0.00      0.00      0.00         3
#         FADS       0.00      0.00      0.00         5
#         FAER       0.92      0.28      0.43       158
#         FAFA       0.77      0.55      0.64       257
#         FAFI       0.99      0.98      0.98       366
#         FALC       0.48      0.88      0.62       143
#         FAML       0.90      0.66      0.76       128
#         FARR       0.83      0.29      0.43        35
#         FASR       1.00      0.43      0.60        21
#         FATA       1.00      0.50      0.67        26
#         FATP       0.00      0.00      0.00         5
#         FLAC       0.97      0.98      0.97       200
#         FLCS       1.00      0.33      0.50         3
#         FLFA       1.00      0.83      0.91        24
#         FLLE       0.83      0.75      0.79        20
#         FLMI       0.76      0.89      0.82        18
#         FLPP       0.82      0.94      0.88        34
#         FLPR       0.82      0.82      0.82        11
#         FLTR       0.97      0.67      0.79        42
#         FLTX       0.92      1.00      0.96        24
#         FLXX       0.90      0.94      0.92       336
#         GDXX       0.83      0.56      0.67         9
#         HCCA       1.00      0.64      0.78        22
#         HCMR       1.00      0.74      0.85        19
#         HRBP       0.73      0.81      0.77        59
#         HRCB       0.93      0.82      0.87        17
#         HRDI       0.00      0.00      0.00         1
#         HRGM       0.00      0.00      0.00         4
#         HROD       0.83      0.36      0.50        14
#         HRRE       0.73      0.89      0.80        76
#         HRSS       0.75      0.30      0.43        10
#         HRTR       0.91      0.59      0.71        34
#         HRXX       1.00      0.58      0.74        12
#         HSGL       0.55      0.61      0.58        46
#         HSLD       0.00      0.00      0.00         3
#         HSPL       0.73      0.65      0.69        17
#         HSRS       1.00      0.60      0.75         5
#         INAU       0.78      0.87      0.82        60
#         INCL       0.86      0.46      0.60        13
#         INDB       0.82      0.85      0.84       172
#         INDC       0.00      0.00      0.00         6
#         INDS       0.77      0.62      0.69        93
#         INFS       0.00      0.00      0.00        12
#         INNE       0.99      0.87      0.93       158
#         INRA       0.90      0.90      0.90       398
#         INRE       1.00      0.93      0.97        15
#         INRI       1.00      0.97      0.98       440
#         INRP       0.44      0.27      0.33        15
#         INSA       1.00      0.58      0.74        24
#         INSS       0.75      0.91      0.82       218
#         INTI       1.00      0.33      0.50         6
#         INXX       0.83      0.87      0.85       499
#         ITAU       1.00      0.10      0.18        10
#         LECO       0.61      0.83      0.70       181
#         LEPO       0.21      0.20      0.21        15
#         LERE       1.00      1.00      1.00         7
#         MBCC       0.91      0.87      0.89        23
#         MBCM       1.00      0.80      0.89         5
#         MBDM       0.90      0.64      0.75        14
#         MBXX       0.53      1.00      0.69        10
#         PDFS       0.00      0.00      0.00        15
#         PDPM       0.82      0.78      0.80       102
#         PDXX       0.98      0.91      0.94      1588
#         PRAG       0.82      0.81      0.81       149
#         PRPO       0.91      0.87      0.89       312
#         PRXX       0.76      0.71      0.73       393
#         QAXX       0.00      0.00      0.00        10
#         QUTF       0.72      0.73      0.73        93
#         QUTS       0.93      0.93      0.93       217
#         RABA       0.80      0.80      0.80       337
#         RABF       0.76      0.93      0.84        97
#         RAPR       0.67      0.67      0.67         3
#         RARA       0.91      0.75      0.82       255
#         RASR       0.97      0.80      0.88        35
#         RAVA       0.91      0.84      0.88        76
#         RICR       0.54      0.72      0.62        76
#         RIER       0.96      0.48      0.64        56
#         RIMR       0.32      0.41      0.36        91
#         RIOR       0.93      0.88      0.91       373
#         RSSC       1.00      1.00      1.00         3
#         RSVM       0.91      0.45      0.61        22
#         RSWL       0.00      0.00      0.00         1
#         SAAC       0.91      0.84      0.87        25
#         SABD       0.97      0.80      0.88        46
#         SACS       1.00      0.67      0.80         6
#         SAPS       0.67      0.57      0.62         7
#         SASD       0.65      0.62      0.63        21
#         SAXX       0.76      0.87      0.81        39
#         SCCP       1.00      0.94      0.97        51
#         SSSO       0.90      0.88      0.89        32
#         SYAS       1.00      0.45      0.62        11
#         SYGR       1.00      0.38      0.55        34
#         SYIM       0.96      0.81      0.88        90
#         SYIN       1.00      0.65      0.79        23
#         SYIS       0.57      0.67      0.62        36
#         SYPT       0.00      0.00      0.00         3
#         SYXX       0.90      0.79      0.84       321
#         TEAU       0.89      0.93      0.91      1090
#         TEMT       0.92      0.67      0.77        51
#         TEXX       0.99      0.95      0.97       544
#         TOCO       0.88      0.90      0.89       829
#         TOFC       0.94      0.93      0.94      1419
#         TOFS       0.79      0.86      0.82        83
#         TOMR       0.95      0.54      0.69        39
#         TOPO       0.70      0.69      0.69        61
#         TOSI       0.77      0.97      0.86       810
#         TRPR       0.92      0.55      0.69        22
#         TWXX       0.93      0.74      0.83        35
#         UEXX       1.00      0.79      0.88        14
#         Unma       1.00      0.98      0.99       750
#         VATR       0.00      0.00      0.00         1
#         asxx       0.00      0.00      0.00         2
#         bfam       0.00      0.00      0.00         2
#         cmdo       0.00      0.00      0.00         3
#         dmda       0.00      0.00      0.00         2
#         edxx       1.00      0.67      0.80         3
#         hrdi       0.00      0.00      0.00         1
#         indb       0.00      0.00      0.00         1
#         inds       0.00      0.00      0.00         3
#         pdxx       0.00      0.00      0.00         4
#         rabf       1.00      1.00      1.00         2
#         rsvm       0.00      0.00      0.00         1
#         teau       0.67      0.40      0.50         5
#
#     accuracy                           0.84     30498
#    macro avg       0.69      0.56      0.60     30498
# weighted avg       0.85      0.84      0.84     30498
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Level

# %%
# Train logistic regression model
model_2 = LogisticRegression()
model_2.fit(X_train_2, y_train_2)

# Predict on test set and evaluate performance
y_pred_2 = model_2.predict(X_test_2)
print('Accuracy:', accuracy_score(y_test_2, y_pred_2))
print('Classification Report:\n', classification_report(y_test_2, y_pred_2))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy: 0.730670863663191
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      0.71      0.83         7
#            2       0.45      0.36      0.40        39
#            3       0.52      0.55      0.54        62
#            4       0.71      0.56      0.62        43
#            5       0.68      0.68      0.68        19
#            6       0.50      0.11      0.18         9
#            7       0.00      0.00      0.00         2
#           E1       0.62      0.22      0.33        58
#           E2       0.62      0.45      0.53        11
#           I0       1.00      0.75      0.86         4
#           I1       0.70      0.83      0.76      4530
#           I2       0.67      0.64      0.65      3873
#           I3       0.70      0.56      0.62      3311
#           I4       0.73      0.86      0.79      4872
#           I5       0.75      0.68      0.71      1583
#           I6       0.65      0.16      0.26       248
#           I7       0.33      0.50      0.40        14
#           M2       0.84      0.79      0.81       271
#           M3       0.61      0.51      0.55      1104
#           M4       0.60      0.69      0.64      1236
#           M5       0.62      0.61      0.62      1367
#           M6       0.69      0.49      0.57       505
#           M7       0.70      0.39      0.50       406
#           S1       0.69      0.57      0.63       150
#           S2       0.89      0.91      0.90      2446
#           S3       0.80      0.72      0.76      2498
#           ed       1.00      1.00      1.00       751
#           ow       0.93      0.95      0.94      1079
#
#     accuracy                           0.73     30498
#    macro avg       0.68      0.58      0.61     30498
# weighted avg       0.73      0.73      0.72     30498
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Unseen JF

# %%
X_test_unseen = []

for i, col in enumerate(train_cols):
    vectorizer = vectorizers[i]
    X_test_col = vectorizer.transform(df_test.loc[:, col])
    X_test_unseen.append(X_test_col)

X_unseen = hstack(X_test_unseen)

# %% [markdown]
# JF

# %%
y_test_pred = model.predict (X_unseen)

# %% [markdown]
# Unseen Level + Pred JF

# %%
X_test_unseen_2 = []
z=0
for i, col in enumerate(train_cols):
    vectorizer = vectorizers_2[i]
    X_test_col_2 = vectorizer.transform(df_test.loc[:, col])
    X_test_unseen_2.append(X_test_col_2)
    z=i

vectorizer = vectorizers_2[z+1]
X_test_col_2 = vectorizer.transform(df_test.loc[:, jfcol])
X_test_unseen_2.append(X_test_col_2)

X_unseen_2 = hstack(X_test_unseen_2)

# %% [markdown]
# Level

# %%
y_test_pred_2 = model_2.predict (X_unseen_2)

# %%
pd.DataFrame(y_test_pred).to_csv('JF_x.csv')
pd.DataFrame(y_test_pred_2).to_csv('Lvl_x.csv')
frames=[pd.DataFrame(y_test_pred),pd.DataFrame(y_test_pred_2)]
maps=pd.concat(frames, axis=1)
pd.DataFrame(maps).to_csv('maps_x.csv')

# %% [markdown]
# JF

# %%
# Predict on test set and evaluate performance
y_test_actual=df_test[target_col]
print('Accuracy:', accuracy_score(y_test_actual, y_test_pred))
print('Classification Report:\n', classification_report(y_test_actual, y_test_pred))
# Out:
# Accuracy: 0.9695413109535523
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#         AAMD       0.00      0.00      0.00         0
#         AFFE       0.81      1.00      0.89        17
#         AFSE       1.00      1.00      1.00        19
#         AFXX       0.67      0.43      0.52        14
#         ARXX       1.00      1.00      1.00        31
#         ASUI       0.95      1.00      0.98        21
#         ASXX       0.93      1.00      0.96      7590
#         BFAM       1.00      1.00      1.00        14
#         BFCA       0.99      1.00      1.00       367
#         BFCB       1.00      1.00      1.00      2793
#         BFCM       1.00      0.99      0.99        88
#         BFKY       1.00      1.00      1.00       443
#         BFLP       1.00      1.00      1.00        94
#         BFTF       1.00      1.00      1.00       233
#         BFTO       1.00      1.00      1.00       698
#         BFUW       1.00      1.00      1.00        16
#         BSMT       1.00      1.00      1.00        26
#         CSFC       1.00      1.00      1.00       559
#         DABI       0.99      1.00      1.00       318
#         FAER       1.00      1.00      1.00        24
#         FAFA       1.00      1.00      1.00       249
#         FAFI       1.00      1.00      1.00      1538
#         FLAC       1.00      1.00      1.00       343
#         FLFA       1.00      1.00      1.00        70
#         FLLE       0.70      1.00      0.82         7
#         FLPR       0.00      0.00      0.00         0
#         FLTR       1.00      1.00      1.00        98
#         HRBP       0.94      1.00      0.97        34
#         HRCB       1.00      1.00      1.00         6
#         HRDI       0.00      0.00      0.00         4
#         HROD       0.00      0.00      0.00         1
#         HRRE       0.97      0.88      0.92        76
#         HRTR       0.40      0.86      0.55         7
#         HRXX       0.00      0.00      0.00         3
#         HSPL       0.00      0.00      0.00         1
#         INAU       1.00      1.00      1.00        40
#         INDB       1.00      1.00      1.00       268
#         INNE       1.00      1.00      1.00       116
#         INRA       0.96      1.00      0.98       408
#         INRI       1.00      0.99      0.99      1908
#         INSS       1.00      1.00      1.00       229
#         LECO       1.00      1.00      1.00       103
#         MBCC       1.00      1.00      1.00        19
#         MBXX       0.00      0.00      0.00         0
#         No M       0.00      0.00      0.00       763
#         PDPM       1.00      1.00      1.00       151
#         PRAG       1.00      1.00      1.00       263
#         PRPO       1.00      1.00      1.00       834
#         PRXX       1.00      1.00      1.00       435
#         QUTF       0.92      0.88      0.90        95
#         QUTS       0.98      1.00      0.99       649
#         RABA       1.00      1.00      1.00       592
#         RABF       1.00      1.00      1.00       108
#         RARA       0.96      1.00      0.98       258
#         RICR       0.00      0.00      0.00        10
#         RIER       1.00      0.89      0.94        66
#         RIMR       0.00      0.00      0.00         3
#         RIOR       0.99      1.00      1.00      1101
#         RSSC       1.00      1.00      1.00        24
#         SSSO       1.00      1.00      1.00        94
#         SYXX       1.00      1.00      1.00       485
#         TEAU       1.00      1.00      1.00       194
#         TOCO       1.00      1.00      1.00        43
#         TOFC       1.00      1.00      1.00      1739
#         TOPO       0.83      1.00      0.91        30
#         TOSI       1.00      1.00      1.00       794
#         TWXX       1.00      1.00      1.00        20
#
#     accuracy                           0.97     27644
#    macro avg       0.82      0.83      0.83     27644
# weighted avg       0.95      0.97      0.96     27644
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
df_lvlx = pd.read_csv('maps_x.csv')

# %% [markdown]
# Level

# %%
# Predict on test set and evaluate performance
y_test_actual_2=df_test[target_col_2]
print('Accuracy:', accuracy_score(y_test_actual_2, y_test_pred_2))
print('Classification Report:\n', classification_report(y_test_actual_2, y_test_pred_2))
# Out:
# Accuracy: 0.8655766169874114
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#           E1       1.00      0.18      0.30        28
#           I1       0.89      0.93      0.91      2661
#           I2       0.74      0.81      0.78      2051
#           I3       0.86      0.74      0.80      2761
#           I4       0.91      0.99      0.95      8767
#           I5       0.88      0.93      0.90      2685
#           I6       0.82      0.17      0.27       200
#           I7       0.28      0.26      0.27        19
#           M2       0.92      0.99      0.96       630
#           M3       0.69      0.37      0.48       313
#           M4       0.55      0.52      0.54       332
#           M5       0.63      0.90      0.74       702
#           M6       0.50      0.16      0.24       106
#           M7       0.00      0.00      0.00       104
#           S1       0.00      0.00      0.00         3
#           S2       0.90      0.94      0.92      3021
#           S3       0.88      0.85      0.86      2498
#           ch       0.00      0.00      0.00       763
#
#     accuracy                           0.87     27644
#    macro avg       0.64      0.54      0.55     27644
# weighted avg       0.84      0.87      0.85     27644
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
df_test_2.head()
# Out:
#                         Co. Designation           Co. Function  \
# 0  Senior Information Security Engineer      Technology & Data
# 1     Senior Investment Risk Specialist  Governance & Controls
# 2              Senior Software Engineer      Technology & Data
# 3        Senior Infrastructure Engineer      Technology & Data
# 4              Senior Software Engineer      Technology & Data
#
#   Job Family Code Level
# 0            SYXX    I4
# 1            RIER    I3
# 2            ASXX    I4
# 3            INSS    I4
# 4            ASXX    I4

# %%
temp=df_test_2.loc[:,'TFP']
init_maps=pd.concat([maps , temp], axis=1)
init_maps
# Out:
#           0   0      TFP
# 0      SYXX  I4  2100037
# 1      RIOR  I3  2080500
# 2      ASXX  I4  1743788
# 3      INSS  I4  2071378
# 4      ASXX  I4  3253143
# ...     ...  ..      ...
# 27639  ASXX  I5  4867135
# 27640  ASXX  I5  2996000
# 27641  ASXX  I5  6615000
# 27642  PRPO  I4  2956480
# 27643  HRBP  I5  3500001
#
# [27644 rows x 3 columns]

# %%
init_maps.JF.unique()
# Out:
# array(['SYXX', 'RIOR', 'ASXX', 'INSS', 'INRI', 'PRXX', 'FLTR', 'PRPO',
#        'TOFC', 'PDPM', 'ARXX', 'CSFC', 'RABA', 'TEAU', 'FAFI', 'BFCB',
#        'FLAC', 'BFTO', 'AFFE', 'INRA', 'BFCA', 'TOSI', 'BFLP', 'BFTF',
#        'QUTS', 'BFKY', 'FAFA', 'RARA', 'AFSE', 'MBCC', 'FLFA', 'FAER',
#        'RABF', 'RIER', 'QUTF', 'PRAG', 'DABI', 'INDB', 'SSSO', 'TOPO',
#        'BFAM', 'AAMD', 'BFCM', 'TOCO', 'LECO', 'HRRE', 'HRBP', 'INNE',
#        'HRCB', 'TWXX', 'BSMT', 'AFXX', 'RSSC', 'HRTR', 'FLLE', 'BFUW',
#        'ASUI', 'MBXX', 'INAU', 'FLPR'], dtype=object)

# %%
init_maps.columns = ['JF', 'level', 'TFP']

# %%
ref_table = pd.read_excel('GCC_LOL.xlsx')

# %%
ref_table.head()
# Out:
#   JF+Level    JF Level    P10     P90
# 0   AFADS2  AFAD    S2  283.0   710.0
# 1   AFADS3  AFAD    S3  331.0   840.0
# 2   AFADI1  AFAD    I1  465.0  1004.0
# 3   AFADI2  AFAD    I2  609.0  1334.0
# 4   AFADI3  AFAD    I3  818.0  1936.0

# %%
def find_in_ref(df, jf, level):
  try:
    return df.loc[(df.JF == jf) & (df.Level == level)]
  except:
    return None

def check_range_ref(ref_df, comp, index):
  ref_row = ref_df.loc[ref_df.index == index]

  if comp >= ref_row.P10.values[0] and comp <= ref_row.P90.values[0] :
    return True

  return False

# %%
find_in_ref(ref_table, 'HRBP', 'I5')
# Out:
#     JF+Level    JF Level     P10     P90
# 606   HRBPI5  HRBP    I5  2927.0  5732.0

# %%
reassigned_maps = init_maps.copy(deep=True)

# %%
from tqdm.auto import tqdm

# %%
for index, query in tqdm(init_maps.iterrows()):
  ref_row = find_in_ref(ref_table, query.JF, query.level)

  try:
    ref_index = ref_row.index[0]
  except:
    continue

  # check if comp falls in that range
  comp = query['TFP']/1000
  final_index = -1
  if check_range_ref(ref_table, comp, ref_index):
    #print("Exact match found at ", ref_index)
    final_index = ref_index
  elif check_range_ref(ref_table, comp, ref_index -1 ):
    #print("Exact match found before ref_index, at ", ref_index -1)
    final_index = ref_index - 1
  elif check_range_ref(ref_table, comp, ref_index +1 ):
    #print("Exact match found after index at ", ref_index + 1)
    final_index = ref_index + 1

  if final_index != -1 :
    final_level = ref_table.loc[ref_table.index == final_index].Level.values[0]
    reassigned_maps.at[final_index, 'level'] = final_level
# Out:
# 0it [00:00, ?it/s]

# %%
pd.DataFrame(reassigned_maps).to_csv('reassigned maps')
