# %% [markdown]
# <a href="https://colab.research.google.com/github/LazyHooks/Optimus/blob/main/optimus_v3_TestInmobi_IncludingTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('Train_1__IncludingTest.csv')
df.head()
# Out:
#      Company Name                  Co. Designation Co. Function  \
# 0  Citrix Systems  Principal Information Developer  Engineering
# 1  Citrix Systems           Staff Quality Engineer  Engineering
# 2  Citrix Systems           Sr Manager Engineering  Engineering
# 3  Citrix Systems            Principal SW Engineer  Engineering
# 4  Citrix Systems          Sr Director Engineering  Engineering
#
#   Job Family Code
# 0            TWXX
# 1            TEAU
# 2            PDXX
# 3            PDXX
# 4            PDXX

# %%
df_test = pd.read_csv('Test_3_Inmobi.csv')
df_test.head()
# Out:
#   Company Name                                 Co. Designation  \
# 0       Inmobi                        Director - Data Sciences
# 1       Inmobi                        Director - Data Sciences
# 2       Inmobi  Director - Strategic Sales and Market Research
# 3       Inmobi            Director - Performance Sales- Europe
# 4       Inmobi                     Global Controller - Finance
#
#           Co. Function Job Family Code
# 0        Data Sciences            AADS
# 1        Data Sciences            AADS
# 2  Platform Specialist            ASXX
# 3         Inside Sales            SAPS
# 4              Finance            FAAG

# %%
df.shape
set(df['Company Name'])
# Out:
# {'Citrix Systems', 'Inmobi'}

# %%
df.columns
# Out:
# Index(['Company Name', 'Co. Designation', 'Co. Function', 'Job Family Code'], dtype='object')

# %%
train_cols = ['Co. Designation', 'Co. Function']

# %%
target_col = 'Job Family Code'

# %%
all_cols = ['Co. Designation', 'Co. Function', 'Job Family Code']

# %%
import pandas as pd
from scipy.sparse import hstack
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split

# %%
# Load data
data = pd.read_csv('Train_1__IncludingTest.csv')

# %%
df_test.head()
# Out:
#   Company Name                                 Co. Designation  \
# 0       Inmobi                        Director - Data Sciences
# 1       Inmobi                        Director - Data Sciences
# 2       Inmobi  Director - Strategic Sales and Market Research
# 3       Inmobi            Director - Performance Sales- Europe
# 4       Inmobi                     Global Controller - Finance
#
#           Co. Function Job Family Code
# 0        Data Sciences            AADS
# 1        Data Sciences            AADS
# 2  Platform Specialist            ASXX
# 3         Inside Sales            SAPS
# 4              Finance            FAAG

# %%
data = data[all_cols]
data = data.dropna()

# %%
df_test = df_test[all_cols]
df_test = df_test.dropna()

# %%
data.head()
# Out:
#                    Co. Designation Co. Function Job Family Code
# 0  Principal Information Developer  Engineering            TWXX
# 1           Staff Quality Engineer  Engineering            TEAU
# 2           Sr Manager Engineering  Engineering            PDXX
# 3            Principal SW Engineer  Engineering            PDXX
# 4          Sr Director Engineering  Engineering            PDXX

# %%
df_test.head()
# Out:
#                                   Co. Designation         Co. Function  \
# 0                        Director - Data Sciences        Data Sciences
# 1                        Director - Data Sciences        Data Sciences
# 2  Director - Strategic Sales and Market Research  Platform Specialist
# 3            Director - Performance Sales- Europe         Inside Sales
# 4                     Global Controller - Finance              Finance
#
#   Job Family Code
# 0            AADS
# 1            AADS
# 2            ASXX
# 3            SAPS
# 4            FAAG

# %%
# Extract features from each text column using TF-IDF vectorizer
vectorizers = []
X_train_list = []
X_test_list = []
for col in train_cols:
    vectorizer = TfidfVectorizer(max_features=10000)
    X_train_col = vectorizer.fit_transform(data.loc[:, col])
    X_train_list.append(X_train_col)
    X_test_col = vectorizer.transform(data.loc[:, col])
    X_test_list.append(X_test_col)
    vectorizers.append(vectorizer)

# %%
# Concatenate sparse matrices into a single feature matrix
X_train = hstack(X_train_list)
X_test = hstack(X_test_list)

# Split data into training and testing sets
y_train = data[target_col]
#y_test = df_test[target_col]

X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# Train logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict on test set and evaluate performance
y_pred = model.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred))
print('Classification Report:\n', classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9196261682242991
# Classification Report:
#                precision    recall  f1-score   support
#
#         AADS       1.00      1.00      1.00         4
#         AFAD       0.00      0.00      0.00         2
#         AFSE       0.00      0.00      0.00         0
#         AFXX       0.00      0.00      0.00         1
#         ASDB       1.00      1.00      1.00         2
#         ASPI       1.00      1.00      1.00         7
#         ASUI       0.00      0.00      0.00         2
#         ASXX       0.00      0.00      0.00         2
#         BCPM       0.00      0.00      0.00         1
#         CCMD       0.89      1.00      0.94         8
#         CSBC       0.50      0.50      0.50         2
#         CSCS       0.00      0.00      0.00         1
#         CSED       1.00      1.00      1.00         2
#         CSFC       0.53      1.00      0.70         8
#         CSSI       1.00      1.00      1.00         2
#         DADV       1.00      1.00      1.00         3
#         FAAG       0.00      0.00      0.00         1
#         FLAC       0.50      0.50      0.50         2
#         FLLE       1.00      1.00      1.00         1
#         FLPP       1.00      0.67      0.80         3
#         FLXX       0.71      0.83      0.77         6
#         GDXX       1.00      1.00      1.00         5
#         HRBP       1.00      0.83      0.91         6
#         HRCB       0.00      0.00      0.00         3
#         HRRE       0.43      1.00      0.60         3
#         HRSS       0.50      1.00      0.67         1
#         HRTR       0.00      0.00      0.00         1
#         INDB       0.00      0.00      0.00         2
#         INFS       1.00      1.00      1.00         2
#         INRA       0.98      1.00      0.99        84
#         INXX       1.00      1.00      1.00         1
#         MBCC       0.00      0.00      0.00         1
#         MBCM       0.00      0.00      0.00         1
#         MBXX       0.62      1.00      0.77         5
#         PDPM       1.00      1.00      1.00        15
#         PDXX       0.97      1.00      0.99       231
#         PRPO       0.00      0.00      0.00         0
#         PRXX       0.75      0.50      0.60         6
#         QUTF       0.67      1.00      0.80         4
#         RABA       1.00      1.00      1.00         4
#         RAPR       1.00      1.00      1.00         3
#         RSSC       0.00      0.00      0.00         0
#         RSWL       0.00      0.00      0.00         1
#         SAAC       0.79      1.00      0.88        23
#         SABD       1.00      0.90      0.95        10
#         SACH       0.00      0.00      0.00         2
#         SACS       1.00      1.00      1.00         4
#         SAIN       0.00      0.00      0.00         1
#         SAPS       0.88      1.00      0.93         7
#         SASD       1.00      0.69      0.82        13
#         SSSO       1.00      0.50      0.67         2
#         SYAS       1.00      0.90      0.95        10
#         SYIM       0.00      0.00      0.00         1
#         SYPT       0.00      0.00      0.00         1
#         TEAU       1.00      1.00      1.00         9
#         TTXX       0.00      0.00      0.00         3
#         TWXX       1.00      0.86      0.92         7
#         UEXX       1.00      1.00      1.00         3
#
#     accuracy                           0.92       535
#    macro avg       0.56      0.58      0.56       535
# weighted avg       0.90      0.92      0.90       535
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
X_test_unseen = []

for i, col in enumerate(train_cols):
    vectorizer = vectorizers[i]
    X_test_col = vectorizer.transform(df_test.loc[:, col])
    X_test_unseen.append(X_test_col)

X_unseen = hstack(X_test_unseen)

# %%
y_test_pred = model.predict (X_unseen)

# %%
pd.DataFrame(y_test_pred).to_csv('maps_gcc')

# %%
# Predict on test set and evaluate performance
y_test_actual=df_test[target_col]
print('Accuracy:', accuracy_score(y_test_actual, y_test_pred))
print('Classification Report:\n', classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9177304964539007
# Classification Report:
#                precision    recall  f1-score   support
#
#         AADS       1.00      1.00      1.00         4
#         AFAD       0.00      0.00      0.00         2
#         AFSE       0.00      0.00      0.00         0
#         AFXX       0.00      0.00      0.00         1
#         ASDB       1.00      1.00      1.00         2
#         ASPI       1.00      1.00      1.00         7
#         ASUI       0.00      0.00      0.00         2
#         ASXX       0.00      0.00      0.00         2
#         BCPM       0.00      0.00      0.00         1
#         CCMD       0.89      1.00      0.94         8
#         CSBC       0.50      0.50      0.50         2
#         CSCS       0.00      0.00      0.00         1
#         CSED       1.00      1.00      1.00         2
#         CSFC       0.53      1.00      0.70         8
#         CSSI       1.00      1.00      1.00         2
#         DADV       1.00      1.00      1.00         3
#         FAAG       0.00      0.00      0.00         1
#         FLAC       0.50      0.50      0.50         2
#         FLLE       1.00      1.00      1.00         1
#         FLPP       1.00      0.67      0.80         3
#         FLXX       0.71      0.83      0.77         6
#         GDXX       1.00      1.00      1.00         5
#         HRBP       1.00      0.83      0.91         6
#         HRCB       0.00      0.00      0.00         3
#         HRRE       0.43      1.00      0.60         3
#         HRSS       0.50      1.00      0.67         1
#         HRTR       0.00      0.00      0.00         1
#         INDB       0.00      0.00      0.00         2
#         INFS       1.00      1.00      1.00         2
#         INRA       0.98      1.00      0.99        84
#         INXX       1.00      1.00      1.00         1
#         MBCC       0.00      0.00      0.00         1
#         MBCM       0.00      0.00      0.00         1
#         MBXX       0.62      1.00      0.77         5
#         PDPM       1.00      1.00      1.00        15
#         PDXX       0.97      1.00      0.99       231
#         PRPO       0.00      0.00      0.00         0
#         PRXX       0.75      0.50      0.60         6
#         QUTF       0.67      1.00      0.80         4
#         RABA       1.00      1.00      1.00         4
#         RAPR       1.00      1.00      1.00         3
#         RSSC       0.00      0.00      0.00         0
#         RSWL       0.00      0.00      0.00         1
#         SAAC       0.79      1.00      0.88        23
#         SABD       1.00      0.90      0.95        10
#         SACH       0.00      0.00      0.00         2
#         SACS       1.00      1.00      1.00         4
#         SAIN       0.00      0.00      0.00         1
#         SAPS       0.88      1.00      0.93         7
#         SASD       1.00      0.69      0.82        13
#         SSSO       1.00      0.50      0.67         2
#         SYAS       1.00      0.90      0.95        10
#         SYIM       0.00      0.00      0.00         1
#         SYPT       0.00      0.00      0.00         1
#         TEAU       1.00      1.00      1.00         9
#         TTXX       0.00      0.00      0.00         3
#         TWXX       1.00      0.86      0.92         7
#         UEXX       1.00      1.00      1.00         3
#
#     accuracy                           0.92       535
#    macro avg       0.56      0.58      0.56       535
# weighted avg       0.90      0.92      0.90       535
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
df_test
# Out:
#                                     Co. Designation         Co. Function  \
# 0                          Director - Data Sciences        Data Sciences
# 1                          Director - Data Sciences        Data Sciences
# 2    Director - Strategic Sales and Market Research  Platform Specialist
# 3              Director - Performance Sales- Europe         Inside Sales
# 4                       Global Controller - Finance              Finance
# ..                                              ...                  ...
# 700                                          SDE II           Technology
# 701                                           SDE I           Technology
# 702                                          SDE II           Technology
# 703                                          SDE II           Technology
# 704                                           SDE I           Technology
#
#     Job Family Code
# 0              AADS
# 1              AADS
# 2              ASXX
# 3              SAPS
# 4              FAAG
# ..              ...
# 700            PDXX
# 701            PDXX
# 702            PDXX
# 703            PDXX
# 704            PDXX
#
# [705 rows x 3 columns]
